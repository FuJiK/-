#  '180.1.3.18',
#  '180.1.4.19',
#  '180.1.5.20',
#  '180.1.6.21',
#  '180.1.7.22',
#  '180.1.8.23',
#  '180.1.9.24',
#  '180.1.10.25',
#  '180.1.11.26',
#  '180.1.12.27',
#  '180.1.13.28',
#  '180.1.14.29',
#  '180.1.15.30',
#  '180.1.16.31',
#  '180.1.17.32',
#  '180.1.18.33',
#  '180.1.19.34',
#  '180.1.20.35',
#  '180.1.21.36',
#  '180.1.22.37',
#  '180.1.23.38',
#  '180.1.24.39',
#  '180.1.25.40',
#  '180.1.26.41',
#  '180.1.27.42',
#  '180.1.28.43',
#  '180.1.29.44',
#  '180.1.30.45',
#  '180.1.31.46',
#  '180.1.32.47',
#  '180.1.33.48',
#  '180.1.34.49',
#  '180.1.35.50',
#  '180.1.36.51',
#  '180.1.37.52',
#  '180.1.38.53',
#  '180.1.39.54',
#  '180.1.40.55',
#  '180.1.41.56',
#  '180.1.42.57',
#  '180.1.43.58',
#  '180.1.44.59',
#  '180.1.45.60',
#  '180.1.46.61',
#  '180.1.47.62',
#  '180.1.48.63',
#  '180.1.49.64',
#  '180.1.50.65',
#  '180.1.51.66',
#  '180.1.52.67',
#  '180.1.53.68',
#  '180.1.54.69',
#  '180.1.55.70',
# ...

# %%
YEAR = "2012"
MONTH = "04"
DATE = "21"
if i < 10:
    for i in range(100):
        print(YEAR+MONTH+DATE+"0"+"test"+str(i)+"0")
elif i >= 10:
    for i in range(100):
        print(YEAR+MONTH+DATE+"0"+str(i))
# Out:
# 2012042100
# 2012042101
# 2012042102
# 2012042103
# 2012042104
# 2012042105
# 2012042106
# 2012042107
# 2012042108
# 2012042109
# 20120421010
# 20120421011
# 20120421012
# 20120421013
# 20120421014
# 20120421015
# 20120421016
# 20120421017
# 20120421018
# 20120421019
# 20120421020
# 20120421021
# 20120421022
# 20120421023
# 20120421024
# 20120421025
# 20120421026
# 20120421027
# 20120421028
# 20120421029
# 20120421030
# 20120421031
# 20120421032
# 20120421033
# 20120421034
# 20120421035
# 20120421036
# 20120421037
# 20120421038
# 20120421039
# 20120421040
# 20120421041
# 20120421042
# 20120421043
# 20120421044
# 20120421045
# 20120421046
# 20120421047
# 20120421048
# 20120421049
# 20120421050
# 20120421051
# 20120421052
# 20120421053
# 20120421054
# 20120421055
# 20120421056
# 20120421057
# 20120421058
# 20120421059
# 20120421060
# 20120421061
# 20120421062
# 20120421063
# 20120421064
# 20120421065
# 20120421066
# 20120421067
# 20120421068
# 20120421069
# 20120421070
# 20120421071
# ...

# %%
l = ['Alice', 'Bob', 'Charlie']
# for name in l:
#     print(name)
# # Alice
# # Bob
# # Charlie
for i, name in enumerate(l, 1):
    print(i, name)
# Out:
# 1 Alice
# 2 Bob
# 3 Charlie

# %%
import pandas as pd

# %%
pd.date_range(start='2018-2-1', periods=10)  #開始と期間を指定
# Out:
# DatetimeIndex(['2018-02-01', '2018-02-02', '2018-02-03', '2018-02-04',
#                '2018-02-05', '2018-02-06', '2018-02-07', '2018-02-08',
#                '2018-02-09', '2018-02-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range(start='2018-2-1', periods=10, freq='D') #開始と期間，単位を指定，1日
# Out:
# DatetimeIndex(['2018-02-01', '2018-02-02', '2018-02-03', '2018-02-04',
#                '2018-02-05', '2018-02-06', '2018-02-07', '2018-02-08',
#                '2018-02-09', '2018-02-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range(start='2018-2-1', periods=10, freq='H') #開始と期間，単位を指定，1時間
# Out:
# DatetimeIndex(['2018-02-01 00:00:00', '2018-02-01 01:00:00',
#                '2018-02-01 02:00:00', '2018-02-01 03:00:00',
#                '2018-02-01 04:00:00', '2018-02-01 05:00:00',
#                '2018-02-01 06:00:00', '2018-02-01 07:00:00',
#                '2018-02-01 08:00:00', '2018-02-01 09:00:00'],
#               dtype='datetime64[ns]', freq='H')

# %%
pd.date_range(start='2018-2-1', periods=10, freq='min') #開始と期間，単位を指定，1分
# Out:
# DatetimeIndex(['2018-02-01 00:00:00', '2018-02-01 00:01:00',
#                '2018-02-01 00:02:00', '2018-02-01 00:03:00',
#                '2018-02-01 00:04:00', '2018-02-01 00:05:00',
#                '2018-02-01 00:06:00', '2018-02-01 00:07:00',
#                '2018-02-01 00:08:00', '2018-02-01 00:09:00'],
#               dtype='datetime64[ns]', freq='T')

# %%
pd.date_range(start='2018-2-1', periods=10, freq='s') #開始と期間，単位を指定，1秒
# Out:
# DatetimeIndex(['2018-02-01 00:00:00', '2018-02-01 00:00:01',
#                '2018-02-01 00:00:02', '2018-02-01 00:00:03',
#                '2018-02-01 00:00:04', '2018-02-01 00:00:05',
#                '2018-02-01 00:00:06', '2018-02-01 00:00:07',
#                '2018-02-01 00:00:08', '2018-02-01 00:00:09'],
#               dtype='datetime64[ns]', freq='S')

# %%
pd.date_range(start='2018-2-1', periods=10, freq='5s') #開始と期間，単位を指定，5秒
# Out:
# DatetimeIndex(['2018-02-01 00:00:00', '2018-02-01 00:00:05',
#                '2018-02-01 00:00:10', '2018-02-01 00:00:15',
#                '2018-02-01 00:00:20', '2018-02-01 00:00:25',
#                '2018-02-01 00:00:30', '2018-02-01 00:00:35',
#                '2018-02-01 00:00:40', '2018-02-01 00:00:45'],
#               dtype='datetime64[ns]', freq='5S')

# %%
pd.date_range(start='2018', periods=10, freq='Y') #開始と期間，単位を指定，１年
# Out:
# DatetimeIndex(['2018-12-31', '2019-12-31', '2020-12-31', '2021-12-31',
#                '2022-12-31', '2023-12-31', '2024-12-31', '2025-12-31',
#                '2026-12-31', '2027-12-31'],
#               dtype='datetime64[ns]', freq='A-DEC')

# %%
pd.date_range(start='2018-2', periods=10, freq='M') #開始と期間，単位を指定，１ヵ月
# Out:
# DatetimeIndex(['2018-02-28', '2018-03-31', '2018-04-30', '2018-05-31',
#                '2018-06-30', '2018-07-31', '2018-08-31', '2018-09-30',
#                '2018-10-31', '2018-11-30'],
#               dtype='datetime64[ns]', freq='M')

# %%
pd.date_range(start='2018-2-1', end='2018-2-10') #開始と終了を指定

pd.date_range(start='2018-2-1', end='2018-2-2', freq='10s') #開始と終了，単位を指定，10秒
# Out:
# DatetimeIndex(['2018-02-01 00:00:00', '2018-02-01 00:00:10',
#                '2018-02-01 00:00:20', '2018-02-01 00:00:30',
#                '2018-02-01 00:00:40', '2018-02-01 00:00:50',
#                '2018-02-01 00:01:00', '2018-02-01 00:01:10',
#                '2018-02-01 00:01:20', '2018-02-01 00:01:30',
#                ...
#                '2018-02-01 23:58:30', '2018-02-01 23:58:40',
#                '2018-02-01 23:58:50', '2018-02-01 23:59:00',
#                '2018-02-01 23:59:10', '2018-02-01 23:59:20',
#                '2018-02-01 23:59:30', '2018-02-01 23:59:40',
#                '2018-02-01 23:59:50', '2018-02-02 00:00:00'],
#               dtype='datetime64[ns]', length=8641, freq='10S')

# %%
df = pd.date_range(start='2018-2-1', end='2018-2-2', freq='1h') #開始と終了，単位を指定，10秒

# %%
l1 = ["20120426010000","20120426020000","20120426030000"]
squares

for i in l1:
    for j in squares:
        print(i, j)
# Out:
# 20120426010000 180.1.0.15
# 20120426010000 180.1.1.16
# 20120426010000 180.1.2.17
# 20120426010000 180.1.3.18
# 20120426010000 180.1.4.19
# 20120426010000 180.1.5.20
# 20120426010000 180.1.6.21
# 20120426010000 180.1.7.22
# 20120426010000 180.1.8.23
# 20120426010000 180.1.9.24
# 20120426010000 180.1.10.25
# 20120426010000 180.1.11.26
# 20120426010000 180.1.12.27
# 20120426010000 180.1.13.28
# 20120426010000 180.1.14.29
# 20120426010000 180.1.15.30
# 20120426010000 180.1.16.31
# 20120426010000 180.1.17.32
# 20120426010000 180.1.18.33
# 20120426010000 180.1.19.34
# 20120426010000 180.1.20.35
# 20120426010000 180.1.21.36
# 20120426010000 180.1.22.37
# 20120426010000 180.1.23.38
# 20120426010000 180.1.24.39
# 20120426010000 180.1.25.40
# 20120426010000 180.1.26.41
# 20120426010000 180.1.27.42
# 20120426010000 180.1.28.43
# 20120426010000 180.1.29.44
# 20120426010000 180.1.30.45
# 20120426010000 180.1.31.46
# 20120426010000 180.1.32.47
# 20120426010000 180.1.33.48
# ...

# %%
import csv
word = "red , blue"
words = word . split(',')
with open('example.csv' , 'w') as f: #　’w’＝書き込み
    writer = csv.writer(f)
    writer.writerow(words)

# %%
import csv
# l1 = ["20120426010000","20120426020000","20120426030000","20120426040000","20120426050000","20120426060000","20120426070000","20120426080000","20120426090000","20120426100000","20120426110000","20120426120000"]
l1 = ["20120503070000","20120503080000","20120503090000","20120503100000","20120503110000","20120503120000"]
squares
for i in l1:
    for j in squares:
        print(i, j)
words = word . split(',')
with open('time.csv' , 'a') as f: #　’w’＝書き込み
    writer = csv.writer(f)
    writer.writerow(words)
# Out:
# .104
# 20120503090000 180.1.90.105
# 20120503090000 180.1.91.106
# 20120503090000 180.1.92.107
# 20120503090000 180.1.93.108
# 20120503090000 180.1.94.109
# 20120503090000 180.1.95.110
# 20120503090000 180.1.96.111
# 20120503090000 180.1.97.112
# 20120503090000 180.1.98.113
# 20120503090000 180.1.99.114
# 20120503090000 180.1.100.115
# 20120503090000 180.1.101.116
# 20120503090000 180.1.102.117
# 20120503090000 180.1.103.118
# 20120503090000 180.1.104.119
# 20120503090000 180.1.105.120
# 20120503090000 180.1.106.121
# 20120503090000 180.1.107.122
# 20120503090000 180.1.108.123
# 20120503090000 180.1.109.124
# 20120503090000 180.1.110.125
# 20120503090000 180.1.111.126
# 20120503090000 180.1.112.127
# 20120503090000 180.1.113.128
# 20120503090000 180.1.114.129
# 20120503090000 180.1.115.130
# 20120503090000 180.1.116.131
# 20120503090000 180.1.117.132
# 20120503090000 180.1.118.133
# 20120503090000 180.1.119.134
# 20120503090000 180.1.120.135
# 20120503090000 180.1.121.136
# ...

# %%
import csv
 
with open('test.csv') as csvfile:
    result = csv.reader(csvfile)
    for row in result:
        print(', '.join(row))
# Out:
# 1, 2, 3, 4
# ABC, DEF, SSS
